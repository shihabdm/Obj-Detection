# %% [markdown]
# <a href="https://colab.research.google.com/github/shihabdm/Obj-Detection/blob/main/Detectron2ObjectModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing required libraries

# %%
# !pip install pyyaml==5.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 27.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp310-cp310-linux_x86_64.whl size=44090 sha256=fed023ee5a68d689f071d959a8488b3d15001eba7f234d9d87e63ba70cfa9dec
#   Stored in directory: /root/.cache/pip/wheels/70/83/31/975b737609aba39a4099d471d5684141c1fdc3404f97e7f68a
# Successfully built pyyaml
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask 2022.12.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# ...

# %%
#Import torch to identify version for torch and cuda
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.0.0+cu118
# True

# %%
# Detectron2 has not released pre-built binaries for the latest pytorch (https://github.com/facebookresearch/detectron2/issues/4053)
# so we install from source instead. This takes a few minutes.

# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# exit(0)  # After installation, you may need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-kcv5w0nf
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-kcv5w0nf
#   Resolved https://github.com/facebookresearch/detectron2.git to commit e020497c85873c2b811ac87dd2e4a34a806e4c2b
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
#successfully installed all requirements

# %% [markdown]
# # Labelme Installation

# %% [markdown]
# 1.   Install labelme via Terminal using the following link:
# https://anaconda.org/conda-forge/labelme (if asked to over-write permissions: click 'Yes')
# 2.   Re-start Anaconda. When opening it, will see labelme as one of the applications to select
# 3.   Using Labelme -
# File >> (Tick) Save Automatically
# File >> (Tick) Save with Image Data
# View >> (Tick) Flags + Label List + Polygon Labels + File List + Fill Drawing Polygon
# 4.   Annotate for each object by 'Create Polygon' + trace for each object then once complete, label it using appropriate descriptor (use these categories for future annotations)
#
# https://gilberttanner.com/blog/detectron2-train-a-instance-segmentation-model/
#
# https://gilberttanner.com/blog/detectron-2-object-detection-with-pytorch/
#
# https://awkvect.com/data-annotation-tool-analysis-how-to-use-labelme/
#
# https://www.youtube.com/watch?v=XtYUPe_JfRw
#
# 5. Save one 'test' folder with a couple, save rest of files in 'training' folder and download labelme2coco.py file

# %% [markdown]
# # Files to Upload to Instance

# %% [markdown]
# Upload the following files:
#
# ![Screen Shot 2023-03-26 at 10.28.36 pm.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-03-26 at 10.29.29 pm.png](data:image/png;base64,...)

# %% [markdown]
# labelm2coco.py retrieve from:
# https://github.com/Tony607/labelme2coco/blob/master/labelme2coco.py?ref=gilberttanner.com

# %% [markdown]
# *italicised text*# New section

# %% [markdown]
# # JSON to COCO conversion
#
# Video link to help:
# https://www.youtube.com/watch?v=ffTURA0JM1Q

# %%
#installing labelme for the instance
# !pip install labelme
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 64.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 91.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 86.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 35.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 13.1 MB/s eta 0:00:00
# ...
#   Created wheel for labelme: filename=labelme-5.2.0.post4-py3-none-any.whl size=1466817 sha256=33870ce7028aa93b37dca17940dcbff68c0e2d35b914bbb460bfbff42c5da4ed
#   Stored in directory: /root/.cache/pip/wheels/d2/23/86/d935212181d03db0703850dba8a2aaa1556de720e6e0be65c5
# Successfully built labelme
# ...

# %%
run labelme2coco.py train --output train.json
# Out:
# save coco json
# train.json

# %%
run labelme2coco.py test --output test.json
# Out:
# save coco json
# test.json

# %% [markdown]
# **Result:**
# Once these are run, the .json files have been generated in the directory
#
#
# ![Screen Shot 2023-03-26 at 10.51.58 pm.png](data:image/png;base64,...)

# %% [markdown]
# # Model Training
#
# Main video link to help: https://www.youtube.com/watch?v=GoItxr16ae8

# %% [markdown]
# *   List item
# *   List item
#
#
#
# 1.   Write the **train.py**, **test.py** and **utils.py** files and write corresponding code
# 2.   Need to select an appropriate model via the Detectron2 Model Zoo link:
# https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md
# (will be useful in train.py code)
# 3. Import train.py, test.py and utils.py files
#
# 4. Then do run train.py and test.py

# %%
run train.py
# Out:
# WARNING [05/02 01:17:44 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/02 01:17:44 d2.data.datasets.coco]: Loaded 29 images in COCO format from train.json
# [05/02 01:17:51 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
run test.py
# Out:
# [05/02 01:27:34 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/object_detection/model_final.pth ...

# %%
from google.colab import drive
drive.mount('/content/drive')
